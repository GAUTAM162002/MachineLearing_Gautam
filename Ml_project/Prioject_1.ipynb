# %% [markdown]
# ## IBM HR Analytics

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

df =pd.read_csv(r"C:\Users\harsh\OneDrive\Desktop\GIT HUB\MachineLearing_Gautam\Ml_project\datasets(02)\WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df['Attrition'],df['DailyRate']
# Out:
# (0       Yes
#  1        No
#  2       Yes
#  3        No
#  4        No
#         ...
#  1465     No
#  1466     No
#  1467     No
#  1468     No
#  1469     No
#  Name: Attrition, Length: 1470, dtype: object,
#  0       1102
#  1        279
#  2       1373
#  3       1392
#  4        591
#          ...
#  1465     884
#  1466     613
#  1467     155
#  1468    1023
#  1469     628
#  Name: DailyRate, Length: 1470, dtype: int64)

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df['Attrition'].value_counts(normalize=True)
# Out:
# Attrition
# No     0.838776
# Yes    0.161224
# Name: proportion, dtype: float64

# %%
df['Attrition'].value_counts(normalize=True)*100
# Out:
# Attrition
# No     83.877551
# Yes    16.122449
# Name: proportion, dtype: float64

# %%
df['EmployeeCount'].unique()
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1465    1
# 1466    1
# 1467    1
# 1468    1
# 1469    1
# Name: EmployeeCount, Length: 1470, dtype: int64

# %%
df['Attrition'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df_bi=df[['Age','Gender','MaritalStatus','BusinessTravel','Attrition']]

df_bi
# Out:
#       Age  Gender MaritalStatus     BusinessTravel Attrition
# 0      41  Female        Single      Travel_Rarely       Yes
# 1      49    Male       Married  Travel_Frequently        No
# 2      37    Male        Single      Travel_Rarely       Yes
# 3      33  Female       Married  Travel_Frequently        No
# 4      27    Male       Married      Travel_Rarely        No
# ...   ...     ...           ...                ...       ...
# 1465   36    Male       Married  Travel_Frequently        No
# 1466   39    Male       Married      Travel_Rarely        No
# 1467   27    Male       Married      Travel_Rarely        No
# 1468   49    Male       Married  Travel_Frequently        No
# 1469   34    Male       Married      Travel_Rarely        No
#
# [1470 rows x 5 columns]

# %%
df=Hourly_rate.corr(Monthly_salary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df=Hourly_rate.corr(Monthly_salary)
#
# NameError: name 'Hourly_rate' is not defined
