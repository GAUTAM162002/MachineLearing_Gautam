# %% [markdown]
# Ml StudyCamp-week1_intro- written by Gautam

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
medical_df = pd.read_csv("../../datasets/medical (1).csv")
